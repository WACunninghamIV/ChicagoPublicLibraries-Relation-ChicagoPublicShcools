# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Libararies_Chicago.csv"
library_df = pd.read_csv(csv_file)
library_df.head()
# Out:
#                                                                                                                                                                             Libraries_-_Locations__Hours_and_Contact_Information
# NAME           HOURS OF OPERATION                                 ADDRESS               CITY    STATE ZIP   PHONE                   WEBSITE                                                                           LOCATION
# Jefferson Park NaN                                                5363 W. Lawrence Ave. Chicago IL    60630 Closed for Construction https://www.chipublib.org/locations/38/            (41.96759739182978, -87.76155426232721)
# Merlo          NaN                                                644 W. Belmont Ave.   Chicago IL    60657 Closed for Construction https://www.chipublib.org/locations/51/           (41.940084208613214, -87.64614322696454)
# ...

# %%
library_df.reset_index(inplace = True)
library_df.columns = library_df.iloc[0]
library_df.drop(library_df.index[0],inplace=True)
library_df.head()
# Out:
# 0           NAME                                  HOURS OF OPERATION  \
# 1  Jefferson Park                                                NaN
# 2           Merlo                                                NaN
# 3        Douglass                                                NaN
# 4     Albany Park  Sun., Closed; Mon. & Wed., 10-6; Tue. & Thu., ...
# 5         Altgeld  Sun., Closed; Mon. & Wed., Noon-8; Tue. & Thu....
#
# 0                ADDRESS     CITY STATE    ZIP                    PHONE  \
# 1  5363 W. Lawrence Ave.  Chicago    IL  60630  Closed for Construction
# 2    644 W. Belmont Ave.  Chicago    IL  60657  Closed for Construction
# 3       3353 W. 13th St.  Chicago    IL  60623  Closed for Construction
# 4    3401 W. Foster Ave.  Chicago    IL  60625           (773) 539-5450
# 5  13281 S. Corliss Ave.  Chicago    IL  60827           (312) 747-3270
#
# 0                                  WEBSITE  \
# 1  https://www.chipublib.org/locations/38/
# ...

# %%
csv_file = "Public_Schools_Chicago.csv"
school_df = pd.read_csv(csv_file)
school_df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
school_df.reset_index(inplace = True)
school_df.columns = school_df.iloc[0]
school_df.drop(school_df.index[0],inplace=True)
school_df.head()
# Out:
# 0 School ID                             Name of School  \
# 1    609966        Charles G Hammond Elementary School
# 2    610539            Marvin Camras Elementary School
# 3    609852           Eliza Chappell Elementary School
# 4    609835         Daniel R Cameron Elementary School
# 5    610521  Sir Miles Davis Magnet Elementary Academy
#
# 0 Elementary, Middle, or High School         Street Address     City State  \
# 1                                 ES         2819 W 21st Pl  Chicago    IL
# 2                                 ES       3000 N Mango Ave  Chicago    IL
# 3                                 ES      2135 W Foster Ave  Chicago    IL
# 4                                 ES  1234 N Monticello Ave  Chicago    IL
# 5                                 ES      6730 S Paulina St  Chicago    IL
#
# 0 ZIP Code    Phone Number                                              Link   \
# 1    60623  (773) 535-4580  http://schoolreports.cps.edu/SchoolProgressRep...
# ...

# %%
#school_df.rename(index = {"ZIP Code":"ZIP"}, 
          #inplace = True)

# %%
#school_df

# %%
merged_inner = pd.merge(left=school_df,right=library_df, left_on='ZIP Code', right_on='ZIP')

merged_inner
# Out:
# 0    School ID                                 Name of School  \
# 0       609966            Charles G Hammond Elementary School
# 1       609966            Charles G Hammond Elementary School
# 2       609966            Charles G Hammond Elementary School
# 3       610056              Roswell B Mason Elementary School
# 4       610056              Roswell B Mason Elementary School
# ...        ...                                            ...
# 1068    609849             George F Cassell Elementary School
# 1069    610082              Mount Greenwood Elementary School
# 1070    609753  Chicago High School for Agricultural Sciences
# 1071    609990                   South Loop Elementary School
# 1072    609678  William Jones College Preparatory High School
#
# 0    Elementary, Middle, or High School         Street Address     City State  \
# 0                                    ES         2819 W 21st Pl  Chicago    IL
# ...
